# %%
import csv
import pandas as pd
import re

from collections import defaultdict

# %%
def is_valid_word(token):
    return re.sub(r'[^\wþȝð-]', '', token)

# %%
def analyze_middle_english_text(filepath):
    word_freq = defaultdict(int)
    word_lines = defaultdict(list)
    all_lines = {}

    with open(filepath, 'r', encoding='utf-8') as f:
        for line_number, line in enumerate(f, 1):
            original_line = line.rstrip("\n")
            all_lines[line_number] = original_line
            tokens = re.split(r'\s+|--', line.lower())
            for token in tokens:
                word = is_valid_word(token)
                if word:
                    word_freq[word] += 1
                    if line_number not in [ln for ln, _ in word_lines[word]]:
                        word_lines[word].append((line_number, original_line.strip()))

    # Prepare rows for CSV or DataFrame
    output_rows = []
    for word in sorted(word_freq.keys()):
        lines = word_lines[word]
        first_line = lines[0]
        output_rows.append([word, word_freq[word], first_line[0], first_line[1]])
        for line_info in lines[1:]:
            output_rows.append(["", "", line_info[0], line_info[1]])

    return output_rows

# %%
def export_to_csv(data, output_path):
    df = pd.DataFrame(data, columns=['Word', 'Frequency', 'Line Number', 'Line Content'])
    df.to_csv(output_path, index=False, encoding='utf-8')
    print(f"Output saved to {output_path}")

# %%
if __name__ == "__main__":
    filepath = '../translated_emotions/corpus/full-sggk.txt'
    output_csv = 'word_occurrences.csv'

    try:
        csv_output = analyze_middle_english_text(filepath)
        df = pd.DataFrame(csv_output, columns=['Word', 'Frequency', 'Line Number', 'Line Content'])
        display(df.head(50))

        # export_to_csv(csv_output, output_csv)
    except FileNotFoundError:
        print("File not found. Please check the filepath.")
# Out:
#    Word Frequency  Line Number  \
# 0     a       271           28
# 1                           59
# 2                           76
# 3                           83
# 4                           92
# 5                          110
# 6                          134
# 7                          152
# 8                          153
# 9                          175
# 10                         176
# 11                         182
# 12                         186
# 13                         190
# 14                         191
# 15                         192
# 16                         194
# 17                         196
# 18                         206
# 19                         208
# 20                         209
# 21                         212
# 22                         214
# 23                         217
# 24                         234
# 25                         243
# 26                         268
# 27                         269
# 28                         281
# 29                         283
# 30                         287
# 31                         294
# 32                         298
# 33                         314
# 34                         335
# 35                         418
# 36                         452
# 37                         457
# 38                         466
# 39                         475
# 40                         481
# 41                         499
# 42                         521
# 43                         538
# 44                         561
# 45                         569
# 46                         572
# 47                         573
# 48                         574
# 49                         589
#
#                                          Line Content
# 0           Þat a selly in siȝt summe men hit holden,
# 1                           So hardy a here on hille.
# 2              Smal sendal bisides, a selure hir ouer
# 3                         A semloker þat euer he syȝe
# 4            Vpon such a dere day er hym deuised were
# 5   And Agrauayn a la dure mayn on þat oþer syde s...
# 6          For vneþe watz þe noyce not a whyle sesed,
# 7   A strayte cote ful streȝt, þat stek on his sides,
# 8               A meré mantile abof, mensked withinne
# 9                        A grene hors gret and þikke,
# 10                       A stede ful stif to strayne,
# 11       A much berd as a busk ouer his brest henges,
# 12          Of a kyngez capados þat closes his swyre;
# 13           Ay a herle of þe here, an oþer of golde;
# 14         Þe tayl and his toppyng twynnen of a sute,
# 15    And bounden boþe wyth a bande of a bryȝt grene,
# 16    Syþen þrawen wyth a þwong a þwarle knot alofte,
# 17    Such a fole vpon folde, ne freke þat hym rydes,
# 18         Bot in his on honde he hade a holyn bobbe,
# 19          And an ax in his oþer, a hoge and vnmete,
# 20   A spetos sparþe to expoun in spelle, quoso myȝt.
# 21             Þe bit burnyst bryȝt, with a brod egge
# 22   Þe stele of a stif staf þe sturne hit bi grypte,
# 23       A lace lapped aboute, þat louked at þe hede,
# 24      Þat a haþel and a horse myȝt such a hwe lach,
# 25            In a swoghe sylence þurȝ þe sale riche;
# 26       I haue a hauberghe at home and a helme boþe,
# 27     A schelde and a scharp spere, schinande bryȝt,
# 28         If I were hasped in armes on a heȝe stede,
# 29      Forþy I craue in þis court a Crystemas gomen,
# 30         Þat dar stifly strike a strok for an oþer,
# 31  And I schal stonde hym a strok, stif on þis flet,
# 32                            A twelmonyth and a day;
# 33          Ouerwalt wyth a worde of on wyȝes speche,
# 34  And wyth a countenaunce dryȝe he droȝ doun his...
# 35  A littel lut with þe hede, þe lere he discouerez,
# 36  Such a dunt as þou hatz dalt--disserued þou ha...
# 37           With a runisch rout þe raynez he tornez,
# 38                          A meruayl among þo menne.
# 39         For I haf sen a selly, I may not forsake.'
# 40    Þenne þay boȝed to a borde þise burnes togeder,
# 41    A ȝere ȝernes ful ȝerne, and ȝeldez neuer lyke,
# 42        To bide a blysful blusch of þe bryȝt sunne.
# 43  And he made a fare on þat fest for þe frekez s...
# 44           To dryȝe a delful dynt, and dele no more
# 45              Fyrst a tulé tapit tyȝt ouer þe flet,
# 46                 Dubbed in a dublet of a dere tars,
# 47          And syþen a crafty capados, closed aloft,
# 48    Þat wyth a bryȝt blaunner was bounden withinne.
# 49                        Gurde wyth a bront ful sure
