# %% [markdown]
# <a href="https://colab.research.google.com/github/clotpoledollophead/SGGK-project/blob/main/middle_english_analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install cltk  # analyzes historical and classical texts, including Middle English
# %pip install nltk 
# %pip install spacy  # advanced text processing (can be customized for Middle English).
# %pip install unidecode  # normalizing text by converting non-standard characters to their closest ASCII equivalents
# %pip install gensim  # topic modeling, text similarity analysis, and other advanced linguistic tasks
# %pip install scikit-learn
# %pip install matplotlib seaborn
# %pip install pandas
# %pip install pytesseract  # enabling digitization of scanned texts (OCR)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cltk in /home/cindy/.local/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.0 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (6.0.2)
# Requirement already satisfied: boltons<22.0.0,>=21.0.0 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (21.0.0)
# Requirement already satisfied: gensim<5.0.0,>=4.3.2 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (4.3.3)
# Requirement already satisfied: gitpython<4.0,>=3.0 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (3.1.43)
# Requirement already satisfied: greek-accentuation<2.0.0,>=1.2.0 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (1.2.0)
# Requirement already satisfied: nltk<4.0,>=3.7 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (3.9.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.4.0 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (3.11.0)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (2.32.3)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.2 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (1.6.0)
# Requirement already satisfied: scipy<1.13.0 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (1.12.0)
# Requirement already satisfied: spacy==3.7.5 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (3.7.5)
# Requirement already satisfied: stanza==1.9.2 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (1.9.2)
# Requirement already satisfied: stringcase<2.0,>=1.2 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (1.2.0)
# Requirement already satisfied: torch!=2.0.1,!=2.1.0,>=2.0.0 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (2.5.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.41.1 in /home/cindy/.local/lib/python3.10/site-packages (from cltk) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (0.15.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (2.10.4)
# Requirement already satisfied: jinja2 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (3.1.5)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy==3.7.5->cltk) (59.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy==3.7.5->cltk) (1.26.4)
# Requirement already satisfied: emoji in /home/cindy/.local/lib/python3.10/site-packages (from stanza==1.9.2->cltk) (2.14.0)
# Requirement already satisfied: protobuf>=3.15.0 in /home/cindy/.local/lib/python3.10/site-packages (from stanza==1.9.2->cltk) (5.29.2)
# Requirement already satisfied: networkx in /home/cindy/.local/lib/python3.10/site-packages (from stanza==1.9.2->cltk) (3.4.2)
# Requirement already satisfied: tomli in /home/cindy/.local/lib/python3.10/site-packages (from stanza==1.9.2->cltk) (2.2.1)
# Requirement already satisfied: smart-open>=1.8.1 in /home/cindy/.local/lib/python3.10/site-packages (from gensim<5.0.0,>=4.3.2->cltk) (7.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/cindy/.local/lib/python3.10/site-packages (from gitpython<4.0,>=3.0->cltk) (4.0.11)
# Requirement already satisfied: click in /home/cindy/.local/lib/python3.10/site-packages (from nltk<4.0,>=3.7->cltk) (8.1.8)
# Requirement already satisfied: joblib in /home/cindy/.local/lib/python3.10/site-packages (from nltk<4.0,>=3.7->cltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/cindy/.local/lib/python3.10/site-packages (from nltk<4.0,>=3.7->cltk) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cindy/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.22.0->cltk) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.22.0->cltk) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.22.0->cltk) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.22.0->cltk) (2020.6.20)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/cindy/.local/lib/python3.10/site-packages (from scikit-learn<2.0.0,>=1.0.2->cltk) (3.5.0)
# Requirement already satisfied: filelock in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (4.12.2)
# Requirement already satisfied: fsspec in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/cindy/.local/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/cindy/.local/lib/python3.10/site-packages (from sympy==1.13.1->torch!=2.0.1,!=2.1.0,>=2.0.0->cltk) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/cindy/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0,>=3.0->cltk) (5.0.1)
# Requirement already satisfied: language-data>=1.2 in /home/cindy/.local/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy==3.7.5->cltk) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/cindy/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.5->cltk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/cindy/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.5->cltk) (2.27.2)
# Requirement already satisfied: wrapt in /home/cindy/.local/lib/python3.10/site-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.3.2->cltk) (1.17.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/cindy/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.5->cltk) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/cindy/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.5->cltk) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /home/cindy/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy==3.7.5->cltk) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/cindy/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy==3.7.5->cltk) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/cindy/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy==3.7.5->cltk) (0.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cindy/.local/lib/python3.10/site-packages (from jinja2->spacy==3.7.5->cltk) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/cindy/.local/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.7.5->cltk) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/cindy/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy==3.7.5->cltk) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/cindy/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy==3.7.5->cltk) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/cindy/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy==3.7.5->cltk) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/cindy/.local/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /home/cindy/.local/lib/python3.10/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/cindy/.local/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/cindy/.local/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/cindy/.local/lib/python3.10/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in /home/cindy/.local/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (2.10.4)
# Requirement already satisfied: jinja2 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy) (59.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/cindy/.local/lib/python3.10/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /home/cindy/.local/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/cindy/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/cindy/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/cindy/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cindy/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/cindy/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/cindy/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/cindy/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/cindy/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/cindy/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/cindy/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/cindy/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cindy/.local/lib/python3.10/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/cindy/.local/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/cindy/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/cindy/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /home/cindy/.local/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /home/cindy/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: unidecode in /home/cindy/.local/lib/python3.10/site-packages (1.3.8)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /home/cindy/.local/lib/python3.10/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /home/cindy/.local/lib/python3.10/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /home/cindy/.local/lib/python3.10/site-packages (from gensim) (1.12.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/cindy/.local/lib/python3.10/site-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /home/cindy/.local/lib/python3.10/site-packages (from smart-open>=1.8.1->gensim) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/cindy/.local/lib/python3.10/site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/cindy/.local/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/cindy/.local/lib/python3.10/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/cindy/.local/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/cindy/.local/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/cindy/.local/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: seaborn in /home/cindy/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cindy/.local/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/cindy/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cindy/.local/lib/python3.10/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/cindy/.local/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/cindy/.local/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/cindy/.local/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cindy/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/cindy/.local/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/cindy/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/cindy/.local/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/cindy/.local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cindy/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/cindy/.local/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytesseract in /home/cindy/.local/lib/python3.10/site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in /home/cindy/.local/lib/python3.10/site-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/lib/python3/dist-packages (from pytesseract) (9.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cltk
import nltk
import spacy as sp
import unidecode as ud
import gensim as gm
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pytesseract as pt
from collections import Counter
import requests
import os

# %%
text_files = ["corpus/passus-i-sggk.txt", "corpus/passus-ii-sggk.txt", "corpus/passus-iii-sggk.txt", "corpus/passus-iv-sggk.txt"]
STOPWORDS_URL = "https://raw.githubusercontent.com/cltk/cltk/master/src/cltk/stops/enm.py"

# %%
def fetch_stopwords(url):
    response = requests.get(url)
    response.raise_for_status()
    content = response.text

    start_marker = "STOPS: list[str] = ["
    start_idx = content.index(start_marker) + len(start_marker)
    end_idx = content.index("]", start_idx)
    stopwords_content = content[start_idx:end_idx].strip()

    stopwords = [
        word.strip().strip('"')
        for word in stopwords_content.split(",")
        if word.strip()
    ]
    return stopwords

# %%
def process_file(filepath, stopwords):
    with open(filepath, "r", encoding="utf-8") as f:
        text = f.read().lower()

    tokens = text.split()

    word_counts_with_stopwords = Counter(tokens)

    tokens_no_stops = [word for word in tokens if word not in stopwords]
    word_counts_without_stopwords = Counter(tokens_no_stops)

    return word_counts_with_stopwords, word_counts_without_stopwords

# %%
def to_dataframe(counter):
    df = pd.DataFrame(counter.items(), columns = ['Word', 'Count'])
    df.sort_values(by = 'Count', ascending = False, inplace = True)
    return df

# %%
stopwords = fetch_stopwords(STOPWORDS_URL)
print(f"Fetched {len(stopwords)} stop words.")

total_with_stopwords = Counter()
total_without_stopwords = Counter()

dfs_with_stopwords = {}
dfs_without_stopwords = {}

for filepath in text_files:
    print(f"Processing: {filepath}")
    counts_with, counts_without = process_file(filepath, stopwords)
    
    total_with_stopwords.update(counts_with)
    total_without_stopwords.update(counts_without)

    file_name = os.path.splitext(os.path.basename(filepath))[0]
    dfs_with_stopwords[file_name] = to_dataframe(counts_with)
    dfs_with_stopwords
    dfs_without_stopwords[file_name] = to_dataframe(counts_without)
    dfs_without_stopwords

total_with_df = to_dataframe(total_with_stopwords)
total_without_df = to_dataframe(total_without_stopwords)
total_with_df
total_without_df
# Out:
# Fetched 275 stop words.
# Processing: corpus/passus-i-sggk.txt
# Processing: corpus/passus-ii-sggk.txt
# Processing: corpus/passus-iii-sggk.txt
# Processing: corpus/passus-iv-sggk.txt
#            Word  Count
# 3          watz    180
# 64          ful    150
# 107         bot    112
# 152          so    110
# 132          ȝe     88
# ...         ...    ...
# 2947     fynde.      1
# 682   þer-vnder      1
# 2949       negh      1
# 2950     inwyth      1
# 5709     pence.      1
#
# [5710 rows x 2 columns]

# %%
# Prepare a DataFrame for the heatmap
combined_df = pd.concat(dfs_with_stopwords, axis=1, keys=dfs_with_stopwords.keys())
combined_df.fillna(0, inplace=True)

# Get top N words for all files
top_words = combined_df.sum(axis=1).sort_values(ascending=False).head(20).index
heatmap_data = combined_df.loc[top_words]

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="coolwarm", cbar=True, linewidths=0.5)
plt.title("Word Count Heatmap Across Text Files", fontsize=16)
plt.xlabel("Files", fontsize=14)
plt.ylabel("Words", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       3 combined_df.fillna(0, inplace=True)
#       5 # Get top N words for all files
# ----> 6 top_words = combined_df.sum(axis=1).sort_values(ascending=False).head(20).index
#       7 heatmap_data = combined_df.loc[top_words]
#       9 # Plot
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11670, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11661 @doc(make_doc("sum", ndim=2))
#   11662 def sum(
#   11663     self,
#    (...)
#   11668     **kwargs,
#   11669 ):
# > 11670     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671     return result.__finalize__(self, method="sum")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:12506, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12498 def sum(
#   12499     self,
#   12500     axis: Axis | None = 0,
#    (...)
#   12504     **kwargs,
#   12505 ):
# > 12506     return self._min_count_stat_function(
#   12507         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:12489, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12486 elif axis is lib.no_default:
#   12487     axis = 0
# > 12489 return self._reduce(
#   12490     func,
#   12491     name=name,
#   12492     axis=axis,
#   12493     skipna=skipna,
#   12494     numeric_only=numeric_only,
#   12495     min_count=min_count,
#   12496 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
#   11563 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564 if out_dtype is not None and out.dtype != "boolean":
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:404, in Block.reduce(self, func)
#     398 @final
#     399 def reduce(self, func) -> list[Block]:
#     400     # We will apply the function and reshape the result into a single-row
#     401     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     402     assert self.ndim == 2
# --> 404     result = func(self.values)
#     406     if self.values.ndim == 1:
#     407         res_values = result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11481, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11479         return np.array([result])
#   11480 else:
# > 11481     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:477, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     474         results = [func(x, **kwargs) for x in arrs]
#     475     return np.array(results)
# --> 477 return func(values, axis=axis, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:646, in nansum(values, axis, skipna, min_count, mask)
#     643 elif dtype.kind == "m":
#     644     dtype_sum = np.dtype(np.float64)
# --> 646 the_sum = values.sum(axis, dtype=dtype_sum)
#     647 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     649 return the_sum
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "float") to str
